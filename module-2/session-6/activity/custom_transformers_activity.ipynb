# %%
import pandas as pd
import numpy as np
from sklearn.base import BaseEstimator, TransformerMixin

# TODO: Modify this list to include the numerical columns
NUMERICAL_VARS = ['pclass', 'survived', 'age', 'sibsp', 'parch', 'fare']

# Crear custom transformer


class MissingIndicator(BaseEstimator, TransformerMixin):

    def __init__(self, variables):
        if not isinstance(variables, list):
            self.variables = [variables]
        else:
            self.variables = variables

    def fit(self, X, y):
        return self

    def transform(self, X):
        # TODO: Put your code here
        for i in self.variables:
            X[i+'_nan'] = np.where(X[i].isnull(), 1, 0)

        return X

# %%
# Leer el csv sin aplicar transformaciones
df = pd.read_csv("C:/Users/IOR_C/OneDrive/Documentos/GitHub/itesm-mlops-irad/module-2/session-6/activity/raw-data.csv")
df
# Out:
#       pclass  survived     sex      age  sibsp  parch      fare cabin  \
# 0          1         1  female  29.0000      0      0  211.3375    B5
# 1          1         1    male   0.9167      1      2  151.5500   C22
# 2          1         0  female   2.0000      1      2  151.5500   C22
# 3          1         0    male  30.0000      1      2  151.5500   C22
# 4          1         0  female  25.0000      1      2  151.5500   C22
# ...      ...       ...     ...      ...    ...    ...       ...   ...
# 1304       3         0  female  14.5000      1      0   14.4542   NaN
# 1305       3         0  female      NaN      1      0   14.4542   NaN
# 1306       3         0    male  26.5000      0      0    7.2250   NaN
# 1307       3         0    male  27.0000      0      0    7.2250   NaN
# 1308       3         0    male  29.0000      0      0    7.8750   NaN
#
#      embarked   title
# 0           S    Miss
# 1           S  Master
# 2           S    Miss
# 3           S      Mr
# ...

# %%
mi = MissingIndicator(variables=NUMERICAL_VARS)

# %%
# Aplicar las transformaciones
df_mi = mi.transform(df)
df_mi
# Out:
#       pclass  survived     sex      age  sibsp  parch      fare cabin  \
# 0          1         1  female  29.0000      0      0  211.3375    B5
# 1          1         1    male   0.9167      1      2  151.5500   C22
# 2          1         0  female   2.0000      1      2  151.5500   C22
# 3          1         0    male  30.0000      1      2  151.5500   C22
# 4          1         0  female  25.0000      1      2  151.5500   C22
# ...      ...       ...     ...      ...    ...    ...       ...   ...
# 1304       3         0  female  14.5000      1      0   14.4542   NaN
# 1305       3         0  female      NaN      1      0   14.4542   NaN
# 1306       3         0    male  26.5000      0      0    7.2250   NaN
# 1307       3         0    male  27.0000      0      0    7.2250   NaN
# 1308       3         0    male  29.0000      0      0    7.8750   NaN
#
#      embarked   title  pclass_nan  survived_nan  age_nan  sibsp_nan  \
# ...
